# %%
"""
Automatically reloads libraries and utilities every time a cell is run
"""
# %load_ext autoreload
# %autoreload 2

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().resolve().parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from utils.PSF_helpers import *
from utils.Plot_helpers import *
from utils.Zernike_helpers import *
from utils.Booth_helpers import *

import numpy as np
import matplotlib.pyplot as plt

# %%
#minor style things to make the figures look nice
plt.style.use("bmh")
plt.rcParams["figure.figsize"] = [548 / 72, 390 / 72]
plt.rcParams["font.size"] = 12
plt.rcParams['text.usetex'] = False
plt.rcParams["figure.dpi"] = 300
#import os
#os.environ["PATH"] += os.pathsep + "/Library/TeX/texbin"

# %%
N_order = 3                # 3 for 3P, 2 for 2P
lambd = 1.3e-3             # Wavelength [mm]
n = 1.333                  # Refractive index
k = 2*n*np.pi/lambd        # Wavenumber
num_apt = 1.05             # Numerical aperture
f = 7.2                    # Focal length of objective (Olympus) [mm]
grid_size = 128            # BFP resolution
L_bfp = 15.12              # BFP diameter [mm]
mag = 4                    # Magnification rate from input to objective
w_0 = 3.5                  # mm
num_apt = 1.05

# %%
r_pupil = f * num_apt
r_bfp = L_bfp / 2
na_eff = num_apt
#effective NA can be limited by the size of the back focal plane
if r_bfp < r_pupil:
    na_eff = r_bfp / f
alpha = np.arcsin(na_eff / n)

theta_grid_size = 64
R_BFP = r_bfp

microscope = Microscope(N_order, lambd, n, num_apt, f, mag, w_0, L_bfp, theta_grid_size)

# %%
L_ffp = 0.012
grid_ffp = 256
grid = Centered_Square_Grid(L_ffp, grid_ffp, 0)
n_beads = 1
bead_img = Bead_Image(grid, np.random.uniform(-0.002, 0.002, n_beads), np.random.uniform(-0.002, 0.002, n_beads), [0.001] * n_beads)

# %%
plot_intensity(*bead_img.get_xy(), bead_img.image_mask)

# %%
mn_preset = [
    [-2, 2], [0, 2], [2, 2],
    [-3, 3], [-1, 3], [1, 3], [3, 3],
    [-4, 4], [-2, 4], [0, 4], [2, 4], [4, 4],
  #  [-5, 5], [-3, 5], [-1, 5], [1, 5], [3, 5], [5, 5],
  #  [-6, 6], [-4, 6], [-2, 6], [0, 6], [2, 6], [4, 6], [6, 6]
]
rng = np.random.default_rng(seed = 15)
strengths = rng.normal(0, .3, len(mn_preset))
innate_aberration = Aberration(mn_preset, strengths)

# %%
slm = SLM(microscope, bead_img, innate_aberration)
# Out:
# Getting unaberrated quality...

# %%
corrected_modes = [
    [-2, 2], [0, 2], [2, 2],
    [-3, 3], [-1, 3], [1, 3], [3, 3],
    [-4, 4], [-2, 4], [0, 4], [2, 4], [4, 4]]
correction_log, quality_log, bias_log, final_correction = slm.run_booth(10, corrected_modes)
# Out:
# ===== Running Booth 2002 Modal AO Algorithm =====
# Noted that only some modes should be corrected.
# Original Aberration:
# n=-2, m=2: -0.429
# n=0, m=2: -0.281
# n=2, m=2: 0.118
# n=-3, m=3: -0.157
# n=-1, m=3: 0.158
# n=1, m=3: 0.242
# n=3, m=3: -0.433
# n=-4, m=4: 0.305
# n=-2, m=4: -0.179
# n=0, m=4: 0.628
# n=2, m=4: 0.219
# n=4, m=4: -0.162
# ===== Iteration 1=====
# Getting raw image quality..
# Image Quality: 0.272
# Applying biases: 0.2 waves
# 	===Optimizing m=-2, n=2===
# 	Exploring plus bias...
# 	Image Quality: 0.217
# 	Exploring minus bias...
# 	Image Quality: 0.332
# 	Evaluating next step...
# 	Computed step to be: -2150938610.055
# 		Rounding up to: -0.2
# 	===Optimizing m=0, n=2===
# 	Exploring plus bias...
# 	Image Quality: 0.241
# 	Exploring minus bias...
# 	Image Quality: 0.368
# 	Evaluating next step...
# 	Computed step to be: -2363215864.035
# 		Rounding up to: -0.2
# 	===Optimizing m=2, n=2===
# 	Exploring plus bias...
# 	Image Quality: 0.353
# 	Exploring minus bias...
# 	Image Quality: 0.293
# 	Evaluating next step...
# 	Computed step to be: 1106659649.563
# 		Rounding down to: 0.2
# 	===Optimizing m=-3, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.275
# 	Exploring minus bias...
# 	Image Quality: 0.223
# 	Evaluating next step...
# 	Computed step to be: 0.114
# 	===Optimizing m=-1, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.264
# 	Exploring minus bias...
# 	Image Quality: 0.292
# 	Evaluating next step...
# 	Computed step to be: -525297901.453
# 		Rounding up to: -0.2
# 	===Optimizing m=1, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.351
# 	Exploring minus bias...
# 	Image Quality: 0.293
# 	Evaluating next step...
# 	Computed step to be: 1090010998.871
# 		Rounding down to: 0.2
# 	===Optimizing m=3, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.305
# 	Exploring minus bias...
# 	Image Quality: 0.226
# 	Evaluating next step...
# 	Computed step to be: 0.612
# 		Rounding down to: 0.2
# 	===Optimizing m=-4, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.268
# 	Exploring minus bias...
# 	Image Quality: 0.293
# 	Evaluating next step...
# 	Computed step to be: -458094010.072
# 		Rounding up to: -0.2
# 	===Optimizing m=-2, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.369
# 	Exploring minus bias...
# 	Image Quality: 0.326
# 	Evaluating next step...
# 	Computed step to be: 812027957.176
# 		Rounding down to: 0.2
# 	===Optimizing m=0, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.264
# 	Exploring minus bias...
# 	Image Quality: 0.365
# 	Evaluating next step...
# 	Computed step to be: -1888589587.49
# 		Rounding up to: -0.2
# 	===Optimizing m=2, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.345
# 	Exploring minus bias...
# 	Image Quality: 0.296
# 	Evaluating next step...
# 	Computed step to be: 903260844.803
# 		Rounding down to: 0.2
# 	===Optimizing m=4, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.241
# 	Exploring minus bias...
# 	Image Quality: 0.274
# 	Evaluating next step...
# 	Computed step to be: -0.112
# ===== Iteration 2=====
# Getting raw image quality..
# Image Quality: 0.196
# Applying biases: 0.16 waves
# 	===Optimizing m=-2, n=2===
# 	Exploring plus bias...
# 	Image Quality: 0.207
# 	Exploring minus bias...
# 	Image Quality: 0.204
# 	Evaluating next step...
# 	Computed step to be: 68449238.239
# 		Rounding down to: 0.16
# 	===Optimizing m=0, n=2===
# 	Exploring plus bias...
# 	Image Quality: 0.224
# 	Exploring minus bias...
# 	Image Quality: 0.169
# 	Evaluating next step...
# 	Computed step to be: 6.539
# 		Rounding down to: 0.16
# 	===Optimizing m=2, n=2===
# 	Exploring plus bias...
# 	Image Quality: 0.183
# 	Exploring minus bias...
# 	Image Quality: 0.217
# 	Evaluating next step...
# 	Computed step to be: -776241491.894
# 		Rounding up to: -0.16
# 	===Optimizing m=-3, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.201
# 	Exploring minus bias...
# 	Image Quality: 0.217
# 	Evaluating next step...
# 	Computed step to be: -356633421.165
# 		Rounding up to: -0.16
# 	===Optimizing m=-1, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.245
# 	Exploring minus bias...
# 	Image Quality: 0.223
# 	Evaluating next step...
# 	Computed step to be: 530673661.854
# 		Rounding down to: 0.16
# 	===Optimizing m=1, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.204
# 	Exploring minus bias...
# 	Image Quality: 0.213
# 	Evaluating next step...
# 	Computed step to be: -196420236.165
# 		Rounding up to: -0.16
# 	===Optimizing m=3, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.195
# 	Exploring minus bias...
# 	Image Quality: 0.235
# 	Evaluating next step...
# 	Computed step to be: -936410782.47
# 		Rounding up to: -0.16
# 	===Optimizing m=-4, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.213
# 	Exploring minus bias...
# 	Image Quality: 0.213
# 	Evaluating next step...
# 	Computed step to be: -12444613.681
# 		Rounding up to: -0.16
# 	===Optimizing m=-2, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.217
# 	Exploring minus bias...
# 	Image Quality: 0.222
# 	Evaluating next step...
# 	Computed step to be: -128566196.416
# 		Rounding up to: -0.16
# 	===Optimizing m=0, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.165
# 	Exploring minus bias...
# 	Image Quality: 0.364
# 	Evaluating next step...
# 	Computed step to be: -4636185325.982
# 		Rounding up to: -0.16
# 	===Optimizing m=2, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.258
# 	Exploring minus bias...
# 	Image Quality: 0.202
# 	Evaluating next step...
# 	Computed step to be: 1320988209.674
# 		Rounding down to: 0.16
# 	===Optimizing m=4, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.195
# 	Exploring minus bias...
# 	Image Quality: 0.232
# 	Evaluating next step...
# 	Computed step to be: -880200982.621
# 		Rounding up to: -0.16
# ===== Iteration 3=====
# Getting raw image quality..
# Image Quality: 0.358
# Applying biases: 0.128 waves
# 	===Optimizing m=-2, n=2===
# 	Exploring plus bias...
# 	Image Quality: 0.367
# 	Exploring minus bias...
# 	Image Quality: 0.379
# 	Evaluating next step...
# 	Computed step to be: -341243115.137
# 		Rounding up to: -0.128
# 	===Optimizing m=0, n=2===
# 	Exploring plus bias...
# 	Image Quality: 0.391
# 	Exploring minus bias...
# 	Image Quality: 0.348
# 	Evaluating next step...
# 	Computed step to be: 1275223079.333
# 		Rounding down to: 0.128
# 	===Optimizing m=2, n=2===
# 	Exploring plus bias...
# 	Image Quality: 0.402
# 	Exploring minus bias...
# 	Image Quality: 0.324
# 	Evaluating next step...
# 	Computed step to be: 2273464787.618
# 		Rounding down to: 0.128
# 	===Optimizing m=-3, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.384
# 	Exploring minus bias...
# 	Image Quality: 0.349
# 	Evaluating next step...
# 	Computed step to be: 1022188643.994
# 		Rounding down to: 0.128
# 	===Optimizing m=-1, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.322
# 	Exploring minus bias...
# 	Image Quality: 0.375
# 	Evaluating next step...
# 	Computed step to be: -0.193
# 		Rounding up to: -0.128
# 	===Optimizing m=1, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.372
# 	Exploring minus bias...
# 	Image Quality: 0.36
# 	Evaluating next step...
# 	Computed step to be: 355148209.988
# 		Rounding down to: 0.128
# 	===Optimizing m=3, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.398
# 	Exploring minus bias...
# 	Image Quality: 0.336
# 	Evaluating next step...
# 	Computed step to be: 1815772435.849
# 		Rounding down to: 0.128
# 	===Optimizing m=-4, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.369
# 	Exploring minus bias...
# 	Image Quality: 0.35
# 	Evaluating next step...
# 	Computed step to be: 576012815.735
# 		Rounding down to: 0.128
# 	===Optimizing m=-2, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.349
# 	Exploring minus bias...
# 	Image Quality: 0.391
# 	Evaluating next step...
# 	Computed step to be: -1211070281.632
# 		Rounding up to: -0.128
# 	===Optimizing m=0, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.341
# 	Exploring minus bias...
# 	Image Quality: 0.497
# 	Evaluating next step...
# 	Computed step to be: -4529182918.97
# 		Rounding up to: -0.128
# 	===Optimizing m=2, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.359
# 	Exploring minus bias...
# 	Image Quality: 0.333
# 	Evaluating next step...
# 	Computed step to be: 0.074
# 	===Optimizing m=4, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.4
# 	Exploring minus bias...
# 	Image Quality: 0.347
# 	Evaluating next step...
# 	Computed step to be: 1549887232.948
# 		Rounding down to: 0.128
# ===== Iteration 4=====
# Getting raw image quality..
# Image Quality: 0.588
# Applying biases: 0.102 waves
# 	===Optimizing m=-2, n=2===
# 	Exploring plus bias...
# 	Image Quality: 0.543
# 	Exploring minus bias...
# 	Image Quality: 0.583
# 	Evaluating next step...
# 	Computed step to be: -0.041
# 	===Optimizing m=0, n=2===
# 	Exploring plus bias...
# 	Image Quality: 0.651
# 	Exploring minus bias...
# 	Image Quality: 0.47
# 	Evaluating next step...
# 	Computed step to be: 0.17
# 		Rounding down to: 0.102
# 	===Optimizing m=2, n=2===
# 	Exploring plus bias...
# 	Image Quality: 0.56
# 	Exploring minus bias...
# 	Image Quality: 0.62
# 	Evaluating next step...
# 	Computed step to be: -2184574617.451
# 		Rounding up to: -0.102
# 	===Optimizing m=-3, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.562
# 	Exploring minus bias...
# 	Image Quality: 0.606
# 	Evaluating next step...
# 	Computed step to be: -0.308
# 		Rounding up to: -0.102
# 	===Optimizing m=-1, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.548
# 	Exploring minus bias...
# 	Image Quality: 0.632
# 	Evaluating next step...
# 	Computed step to be: -3068723357.995
# 		Rounding up to: -0.102
# 	===Optimizing m=1, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.549
# 	Exploring minus bias...
# 	Image Quality: 0.62
# 	Evaluating next step...
# 	Computed step to be: -0.573
# 		Rounding up to: -0.102
# 	===Optimizing m=3, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.567
# 	Exploring minus bias...
# 	Image Quality: 0.583
# 	Evaluating next step...
# 	Computed step to be: -0.033
# 	===Optimizing m=-4, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.622
# 	Exploring minus bias...
# 	Image Quality: 0.55
# 	Evaluating next step...
# 	Computed step to be: 1.1
# 		Rounding down to: 0.102
# 	===Optimizing m=-2, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.632
# 	Exploring minus bias...
# 	Image Quality: 0.533
# 	Evaluating next step...
# 	Computed step to be: 0.504
# 		Rounding down to: 0.102
# 	===Optimizing m=0, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.434
# 	Exploring minus bias...
# 	Image Quality: 0.687
# 	Evaluating next step...
# 	Computed step to be: -0.239
# 		Rounding up to: -0.102
# 	===Optimizing m=2, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.636
# 	Exploring minus bias...
# 	Image Quality: 0.573
# 	Evaluating next step...
# 	Computed step to be: 2274226747.511
# 		Rounding down to: 0.102
# 	===Optimizing m=4, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.559
# 	Exploring minus bias...
# 	Image Quality: 0.605
# 	Evaluating next step...
# 	Computed step to be: -0.221
# 		Rounding up to: -0.102
# ===== Iteration 5=====
# Getting raw image quality..
# Image Quality: 0.753
# Applying biases: 0.082 waves
# 	===Optimizing m=-2, n=2===
# 	Exploring plus bias...
# 	Image Quality: 0.768
# 	Exploring minus bias...
# 	Image Quality: 0.72
# 	Evaluating next step...
# 	Computed step to be: 0.105
# 		Rounding down to: 0.082
# 	===Optimizing m=0, n=2===
# 	Exploring plus bias...
# 	Image Quality: 0.685
# 	Exploring minus bias...
# 	Image Quality: 0.788
# 	Evaluating next step...
# 	Computed step to be: -0.126
# 		Rounding up to: -0.082
# 	===Optimizing m=2, n=2===
# 	Exploring plus bias...
# 	Image Quality: 0.746
# 	Exploring minus bias...
# 	Image Quality: 0.752
# 	Evaluating next step...
# 	Computed step to be: -0.026
# 	===Optimizing m=-3, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.726
# 	Exploring minus bias...
# 	Image Quality: 0.773
# 	Evaluating next step...
# 	Computed step to be: -0.238
# 		Rounding up to: -0.082
# 	===Optimizing m=-1, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.723
# 	Exploring minus bias...
# 	Image Quality: 0.77
# 	Evaluating next step...
# 	Computed step to be: -0.137
# 		Rounding up to: -0.082
# 	===Optimizing m=1, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.784
# 	Exploring minus bias...
# 	Image Quality: 0.728
# 	Evaluating next step...
# 	Computed step to be: 2536046136.461
# 		Rounding down to: 0.082
# 	===Optimizing m=3, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.754
# 	Exploring minus bias...
# 	Image Quality: 0.739
# 	Evaluating next step...
# 	Computed step to be: 0.042
# 	===Optimizing m=-4, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.75
# 	Exploring minus bias...
# 	Image Quality: 0.758
# 	Evaluating next step...
# 	Computed step to be: -347467619.063
# 		Rounding up to: -0.082
# 	===Optimizing m=-2, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.732
# 	Exploring minus bias...
# 	Image Quality: 0.765
# 	Evaluating next step...
# 	Computed step to be: -0.146
# 		Rounding up to: -0.082
# 	===Optimizing m=0, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.746
# 	Exploring minus bias...
# 	Image Quality: 0.732
# 	Evaluating next step...
# 	Computed step to be: 0.019
# 	===Optimizing m=2, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.716
# 	Exploring minus bias...
# 	Image Quality: 0.777
# 	Evaluating next step...
# 	Computed step to be: -0.189
# 		Rounding up to: -0.082
# 	===Optimizing m=4, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.748
# 	Exploring minus bias...
# 	Image Quality: 0.753
# 	Evaluating next step...
# 	Computed step to be: -0.042
# ===== Iteration 6=====
# Getting raw image quality..
# Image Quality: 0.816
# Applying biases: 0.066 waves
# 	===Optimizing m=-2, n=2===
# 	Exploring plus bias...
# 	Image Quality: 0.801
# 	Exploring minus bias...
# 	Image Quality: 0.822
# 	Evaluating next step...
# 	Computed step to be: -0.077
# 		Rounding up to: -0.066
# 	===Optimizing m=0, n=2===
# 	Exploring plus bias...
# 	Image Quality: 0.826
# 	Exploring minus bias...
# 	Image Quality: 0.785
# 	Evaluating next step...
# 	Computed step to be: 0.063
# 	===Optimizing m=2, n=2===
# 	Exploring plus bias...
# 	Image Quality: 0.798
# 	Exploring minus bias...
# 	Image Quality: 0.827
# 	Evaluating next step...
# 	Computed step to be: -0.141
# 		Rounding up to: -0.066
# 	===Optimizing m=-3, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.821
# 	Exploring minus bias...
# 	Image Quality: 0.808
# 	Evaluating next step...
# 	Computed step to be: 0.127
# 		Rounding down to: 0.066
# 	===Optimizing m=-1, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.812
# 	Exploring minus bias...
# 	Image Quality: 0.818
# 	Evaluating next step...
# 	Computed step to be: -0.065
# 	===Optimizing m=1, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.805
# 	Exploring minus bias...
# 	Image Quality: 0.817
# 	Evaluating next step...
# 	Computed step to be: -0.041
# 	===Optimizing m=3, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.817
# 	Exploring minus bias...
# 	Image Quality: 0.806
# 	Evaluating next step...
# 	Computed step to be: 0.043
# 	===Optimizing m=-4, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.821
# 	Exploring minus bias...
# 	Image Quality: 0.809
# 	Evaluating next step...
# 	Computed step to be: 0.157
# 		Rounding down to: 0.066
# 	===Optimizing m=-2, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.83
# 	Exploring minus bias...
# 	Image Quality: 0.793
# 	Evaluating next step...
# 	Computed step to be: 0.121
# 		Rounding down to: 0.066
# 	===Optimizing m=0, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.767
# 	Exploring minus bias...
# 	Image Quality: 0.844
# 	Evaluating next step...
# 	Computed step to be: -0.118
# 		Rounding up to: -0.066
# 	===Optimizing m=2, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.818
# 	Exploring minus bias...
# 	Image Quality: 0.805
# 	Evaluating next step...
# 	Computed step to be: 0.044
# 	===Optimizing m=4, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.801
# 	Exploring minus bias...
# 	Image Quality: 0.824
# 	Evaluating next step...
# 	Computed step to be: -0.112
# 		Rounding up to: -0.066
# ===== Iteration 7=====
# Getting raw image quality..
# Image Quality: 0.832
# Applying biases: 0.052 waves
# 	===Optimizing m=-2, n=2===
# 	Exploring plus bias...
# 	Image Quality: 0.838
# 	Exploring minus bias...
# 	Image Quality: 0.819
# 	Evaluating next step...
# 	Computed step to be: 0.063
# 		Rounding down to: 0.052
# 	===Optimizing m=0, n=2===
# 	Exploring plus bias...
# 	Image Quality: 0.797
# 	Exploring minus bias...
# 	Image Quality: 0.843
# 	Evaluating next step...
# 	Computed step to be: -0.048
# 	===Optimizing m=2, n=2===
# 	Exploring plus bias...
# 	Image Quality: 0.838
# 	Exploring minus bias...
# 	Image Quality: 0.819
# 	Evaluating next step...
# 	Computed step to be: 0.068
# 		Rounding down to: 0.052
# 	===Optimizing m=-3, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.827
# 	Exploring minus bias...
# 	Image Quality: 0.833
# 	Evaluating next step...
# 	Computed step to be: -0.031
# 	===Optimizing m=-1, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.823
# 	Exploring minus bias...
# 	Image Quality: 0.835
# 	Evaluating next step...
# 	Computed step to be: -0.046
# 	===Optimizing m=1, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.843
# 	Exploring minus bias...
# 	Image Quality: 0.813
# 	Evaluating next step...
# 	Computed step to be: 0.089
# 		Rounding down to: 0.052
# 	===Optimizing m=3, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.818
# 	Exploring minus bias...
# 	Image Quality: 0.838
# 	Evaluating next step...
# 	Computed step to be: -0.064
# 		Rounding up to: -0.052
# 	===Optimizing m=-4, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.828
# 	Exploring minus bias...
# 	Image Quality: 0.833
# 	Evaluating next step...
# 	Computed step to be: -0.037
# 	===Optimizing m=-2, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.829
# 	Exploring minus bias...
# 	Image Quality: 0.831
# 	Evaluating next step...
# 	Computed step to be: -0.016
# 	===Optimizing m=0, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.835
# 	Exploring minus bias...
# 	Image Quality: 0.81
# 	Evaluating next step...
# 	Computed step to be: 0.035
# 	===Optimizing m=2, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.805
# 	Exploring minus bias...
# 	Image Quality: 0.846
# 	Evaluating next step...
# 	Computed step to be: -0.08
# 		Rounding up to: -0.052
# 	===Optimizing m=4, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.838
# 	Exploring minus bias...
# 	Image Quality: 0.819
# 	Evaluating next step...
# 	Computed step to be: 0.064
# 		Rounding down to: 0.052
# ===== Iteration 8=====
# Getting raw image quality..
# Image Quality: 0.849
# Applying biases: 0.042 waves
# 	===Optimizing m=-2, n=2===
# 	Exploring plus bias...
# 	Image Quality: 0.846
# 	Exploring minus bias...
# 	Image Quality: 0.85
# 	Evaluating next step...
# 	Computed step to be: -0.033
# 	===Optimizing m=0, n=2===
# 	Exploring plus bias...
# 	Image Quality: 0.854
# 	Exploring minus bias...
# 	Image Quality: 0.836
# 	Evaluating next step...
# 	Computed step to be: 0.043
# 		Rounding down to: 0.042
# 	===Optimizing m=2, n=2===
# 	Exploring plus bias...
# 	Image Quality: 0.844
# 	Exploring minus bias...
# 	Image Quality: 0.852
# 	Evaluating next step...
# 	Computed step to be: -0.061
# 		Rounding up to: -0.042
# 	===Optimizing m=-3, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.852
# 	Exploring minus bias...
# 	Image Quality: 0.844
# 	Evaluating next step...
# 	Computed step to be: 0.079
# 		Rounding down to: 0.042
# 	===Optimizing m=-1, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.85
# 	Exploring minus bias...
# 	Image Quality: 0.847
# 	Evaluating next step...
# 	Computed step to be: 0.058
# 		Rounding down to: 0.042
# 	===Optimizing m=1, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.843
# 	Exploring minus bias...
# 	Image Quality: 0.85
# 	Evaluating next step...
# 	Computed step to be: -0.033
# 	===Optimizing m=3, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.852
# 	Exploring minus bias...
# 	Image Quality: 0.844
# 	Evaluating next step...
# 	Computed step to be: 0.077
# 		Rounding down to: 0.042
# 	===Optimizing m=-4, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.849
# 	Exploring minus bias...
# 	Image Quality: 0.848
# 	Evaluating next step...
# 	Computed step to be: 0.022
# 	===Optimizing m=-2, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.85
# 	Exploring minus bias...
# 	Image Quality: 0.844
# 	Evaluating next step...
# 	Computed step to be: 0.035
# 	===Optimizing m=0, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.833
# 	Exploring minus bias...
# 	Image Quality: 0.858
# 	Evaluating next step...
# 	Computed step to be: -0.072
# 		Rounding up to: -0.042
# 	===Optimizing m=2, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.849
# 	Exploring minus bias...
# 	Image Quality: 0.845
# 	Evaluating next step...
# 	Computed step to be: 0.016
# 	===Optimizing m=4, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.842
# 	Exploring minus bias...
# 	Image Quality: 0.853
# 	Evaluating next step...
# 	Computed step to be: -0.099
# 		Rounding up to: -0.042
# ===== Iteration 9=====
# Getting raw image quality..
# Image Quality: 0.854
# Applying biases: 0.034 waves
# 	===Optimizing m=-2, n=2===
# 	Exploring plus bias...
# 	Image Quality: 0.857
# 	Exploring minus bias...
# 	Image Quality: 0.849
# 	Evaluating next step...
# 	Computed step to be: 0.045
# 		Rounding down to: 0.034
# 	===Optimizing m=0, n=2===
# 	Exploring plus bias...
# 	Image Quality: 0.842
# 	Exploring minus bias...
# 	Image Quality: 0.857
# 	Evaluating next step...
# 	Computed step to be: -0.029
# 	===Optimizing m=2, n=2===
# 	Exploring plus bias...
# 	Image Quality: 0.856
# 	Exploring minus bias...
# 	Image Quality: 0.85
# 	Evaluating next step...
# 	Computed step to be: 0.041
# 		Rounding down to: 0.034
# 	===Optimizing m=-3, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.852
# 	Exploring minus bias...
# 	Image Quality: 0.855
# 	Evaluating next step...
# 	Computed step to be: -0.024
# 	===Optimizing m=-1, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.851
# 	Exploring minus bias...
# 	Image Quality: 0.855
# 	Evaluating next step...
# 	Computed step to be: -0.03
# 	===Optimizing m=1, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.857
# 	Exploring minus bias...
# 	Image Quality: 0.848
# 	Evaluating next step...
# 	Computed step to be: 0.047
# 		Rounding down to: 0.034
# 	===Optimizing m=3, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.849
# 	Exploring minus bias...
# 	Image Quality: 0.856
# 	Evaluating next step...
# 	Computed step to be: -0.041
# 		Rounding up to: -0.034
# 	===Optimizing m=-4, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.853
# 	Exploring minus bias...
# 	Image Quality: 0.854
# 	Evaluating next step...
# 	Computed step to be: -0.01
# 	===Optimizing m=-2, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.853
# 	Exploring minus bias...
# 	Image Quality: 0.854
# 	Evaluating next step...
# 	Computed step to be: -0.006
# 	===Optimizing m=0, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.856
# 	Exploring minus bias...
# 	Image Quality: 0.846
# 	Evaluating next step...
# 	Computed step to be: 0.026
# 	===Optimizing m=2, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.846
# 	Exploring minus bias...
# 	Image Quality: 0.858
# 	Evaluating next step...
# 	Computed step to be: -0.043
# 		Rounding up to: -0.034
# 	===Optimizing m=4, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.856
# 	Exploring minus bias...
# 	Image Quality: 0.849
# 	Evaluating next step...
# 	Computed step to be: 0.044
# 		Rounding down to: 0.034
# ===== Iteration 10=====
# Getting raw image quality..
# Image Quality: 0.859
# Applying biases: 0.027 waves
# 	===Optimizing m=-2, n=2===
# 	Exploring plus bias...
# 	Image Quality: 0.858
# 	Exploring minus bias...
# 	Image Quality: 0.859
# 	Evaluating next step...
# 	Computed step to be: -0.012
# 	===Optimizing m=0, n=2===
# 	Exploring plus bias...
# 	Image Quality: 0.861
# 	Exploring minus bias...
# 	Image Quality: 0.854
# 	Evaluating next step...
# 	Computed step to be: 0.023
# 	===Optimizing m=2, n=2===
# 	Exploring plus bias...
# 	Image Quality: 0.857
# 	Exploring minus bias...
# 	Image Quality: 0.86
# 	Evaluating next step...
# 	Computed step to be: -0.032
# 		Rounding up to: -0.027
# 	===Optimizing m=-3, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.861
# 	Exploring minus bias...
# 	Image Quality: 0.857
# 	Evaluating next step...
# 	Computed step to be: 0.057
# 		Rounding down to: 0.027
# 	===Optimizing m=-1, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.86
# 	Exploring minus bias...
# 	Image Quality: 0.858
# 	Evaluating next step...
# 	Computed step to be: 0.036
# 		Rounding down to: 0.027
# 	===Optimizing m=1, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.856
# 	Exploring minus bias...
# 	Image Quality: 0.861
# 	Evaluating next step...
# 	Computed step to be: -0.029
# 		Rounding up to: -0.027
# 	===Optimizing m=3, n=3===
# 	Exploring plus bias...
# 	Image Quality: 0.861
# 	Exploring minus bias...
# 	Image Quality: 0.857
# 	Evaluating next step...
# 	Computed step to be: 0.042
# 		Rounding down to: 0.027
# 	===Optimizing m=-4, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.859
# 	Exploring minus bias...
# 	Image Quality: 0.859
# 	Evaluating next step...
# 	Computed step to be: -0.004
# 	===Optimizing m=-2, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.859
# 	Exploring minus bias...
# 	Image Quality: 0.858
# 	Evaluating next step...
# 	Computed step to be: 0.012
# 	===Optimizing m=0, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.854
# 	Exploring minus bias...
# 	Image Quality: 0.862
# 	Evaluating next step...
# 	Computed step to be: -0.035
# 		Rounding up to: -0.027
# 	===Optimizing m=2, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.86
# 	Exploring minus bias...
# 	Image Quality: 0.857
# 	Evaluating next step...
# 	Computed step to be: 0.018
# 	===Optimizing m=4, n=4===
# 	Exploring plus bias...
# 	Image Quality: 0.857
# 	Exploring minus bias...
# 	Image Quality: 0.861
# 	Evaluating next step...
# 	Computed step to be: -0.054
# 		Rounding up to: -0.027
# Getting final image at: n=-2, m=2: -0.151
# n=0, m=2: 0.16
# n=2, m=2: -0.009
# n=-3, m=3: -0.023
# n=-1, m=3: -0.425
# n=1, m=3: 0.133
# n=3, m=3: 0.202
# n=-4, m=4: -0.175
# n=-2, m=4: 0.022
# n=0, m=4: -0.644
# n=2, m=4: 0.446
# n=4, m=4: -0.337
# Final image quality: 0.861

# %%
slm.produce_correction_graphic(quality_log, correction_log, final_correction)
